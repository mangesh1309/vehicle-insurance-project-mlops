# %%
import numpy as np

# %%
train_data = np.load(file = "train.npy")

# %%
train_data[0]
# Out:
# array([-1.14855172e+00,  1.05907467e+00,  4.42129350e-02,  2.02008000e+05,
#         1.00000000e+00,  1.00000000e+00,  1.60000000e+01,  0.00000000e+00,
#         1.60000000e+02,  1.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         0.00000000e+00])
